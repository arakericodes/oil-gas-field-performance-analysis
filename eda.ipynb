# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("table_correlation.csv")

# %%
df
# Out:
#   WellID  Depth_m  Operating cost  Total Downtime Hours  Oil(BBL)  Gas(MCF)  \
# 0   W001     2500          823609                   119     20008     58632
# 1   W002     2700          902226                   144     19487     64036
# 2   W003     2600          869079                    92     20498     62574
# 3   W004     3000          903135                   122     19093     65147
# 4   W005     3200          867095                   122     20060     62625
# 5   W006     3100          946519                   140     20612     67134
#
#    Water(BBL)
# 0        7633
# 1        7976
# 2        7145
# 3        7005
# 4        7304
# 5        7997

# %%
df.drop("WellID", axis=1, inplace=True)

# %%
df
# Out:
#    Depth_m  Operating cost  Total Downtime Hours  Oil(BBL)  Gas(MCF)  \
# 0     2500          823609                   119     20008     58632
# 1     2700          902226                   144     19487     64036
# 2     2600          869079                    92     20498     62574
# 3     3000          903135                   122     19093     65147
# 4     3200          867095                   122     20060     62625
# 5     3100          946519                   140     20612     67134
#
#    Water(BBL)
# 0        7633
# 1        7976
# 2        7145
# 3        7005
# 4        7304
# 5        7997

# %%
df_corr = df.corr()

# %%
sns.heatmap(df_corr, annot=True)
# Out:
# <Axes: >

# %%
df.to_csv("heatmap_data.csv")

# %%
sns.pairplot(df)
